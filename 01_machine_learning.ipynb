# %% [markdown]
# # INTRODUCTION TO MACHINE LEARNING

# %% [markdown]
# **Variables:**
#
# - Dependent variable
# - Independent variable
#
#
# **Learning:**
#
# - Supervised learning
# - Unsupervised learning
# - Semisupervised learning
#
#
# **Problems:**
#
# - Regression
# - Classification
#
#
# **Variable types:**
#
# - Numerical variables (quantitative)
# - Categorical variables (qualitative)
#
#
# **Scale types:**
#
# - For numerical variables: Range and ratio
# - For categorical variables: Nominal and ordinal

# %% [markdown]
# **Test-train:**
#
# Divide the data and use one part for training and one part for testing
#
#
# **Feature engineering:**
#
# Creating variables
#
#
# **Variable selection:**
#
# Variables that are not successful and distinctive are deactivated
#
#
# **Model selection:**
#
# - Selecting the best model from the models created with different variable combinations
# - Selecting model from differently created models
#
# **Model is selected according to:**
#
# - For regression -> explainablity ratio and an RMSE-similar value
# - For classification -> a true classification ratio-similar value
#
#
# **Overfitting:**
#
# Model loses its randomness
#
#
# **Deterministic models vs stochastic models:**
#
# - deterministic -> there is a certain relation between variables
# - stochastic ->
#
#
# **Linear models vs nonlinear models:**
#
# -

# %% [markdown]
# ## Model Validation Methods
#
# evaluating the results produced by models
#
#
# **Holdout method**
#
# - original data set is divided into 2 as train set (2/3) and test set (1/3)
#
#
# **K fold cross validation**
#
# - Divide dataset into 5, create the model excluding one part each time and test the model by using excluded part
# - Finf the validation error by estimating mean of errors
#
#
# **Leave one out**
#
# - a special version of k fold cross validation
# - n set = n observation -> numbers are equal
#
#
# **Bootstrap**
#
# -

# %% [markdown]
# ## Model Success Evaluation Methods
#
#
# **- REGRESSION**
#
#
# **Mean squared error**
#
# ![](img1.jpg)
#
# **n** = observation count
# **yi** = real values
# **yî** = predicted values
#
# error per observation
# smaller MSE is better, more successful
#
#
# **Root mean square error**
#
# ![](img2.jpg)
#
#
# **Mean absolute error**
#
# ![](img3.jpg)
#
#
# **- CLASSIFICATION**
#
#
# **Confusion matrix**
#
# ![](img4.jpg)
#
# higher certainity -> more successful model
#
#
# **ROC curve**
#
# ![](img5.jpg)
#
# discrete line -> reference

# %% [markdown]
# ## Bias - Variance Tradeoff
#
# - Model validation
# - Evaluation of the success of the model by looking at real values and predicted values
# - Evaluate train error and test error of the model
#
#
#
# **Bias - variance**
#
# ![](img6.jpg)
#
# **underfitting:** function learned inadequately, not successful, not flexible, high bias
# **accurate model:** low bias, low variance, true flexibility
# **overfitting:** over learned, high variance, high flexibility, high variance means model is not for general-using; it's specific
#
#
# **Train error vs test error**
#
# ![](img7.jpg)

# %% [markdown]
# ## Parameter, Hyperparameter, Parameter Tuning, Model Tuning
#
# - To increase model prediction performance
#
# **Parameter:** inner coefficients in the model - regression coefficients
#
# **Hyperparameter:** exterior values that are found by the used by trying different values in order to optimize the model
#
# **Parameter tuning:** Setting parameters for optimization; it can be used for parameters and hyperparameters
#
# **Model tuning:** Finding model parameters by using hyperparameters, feature engineering without hyperparameter, choosing variable, choosing model, improving the model by hyperparameters are the parts of model tuning
